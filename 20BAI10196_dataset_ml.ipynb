# %%
from sklearn import tree
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = read_csv('Downloads\student_feedback.csv')
df
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 0              0         340                             5
# 1              1         253                             6
# 2              2         680                             7
# 3              3         806                             9
# 4              4         632                             8
# ...          ...         ...                           ...
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# ...

# %%
df.hist()
plt.show()

# %%
df.plot.bar()
plt.show()

# %%
plt.scatter(df['Degree of difficulty of assignments'],df['Use of presentations'])
plt.xlabel('Degree of difficulty of assignments')
plt.ylabel('Use of presentations')
plt.title('scatter plot on student feedback survey form dataset')
# Out:
# Text(0.5, 1.0, 'scatter plot on student feedback survey form dataset')

# %%
plt.pie(df['Well versed with the subject'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
labels=['0-50','51-100','101-150','151-200']
colors=['blue','yellow','green','orange']
sizes=[50,100,150,200]
plt.pie(sizes,labels=labels,colors=colors,startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
df.boxplot(by ='Degree of difficulty of assignments',grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'Course recommendation based on relevance'}, xlabel='[Degree of difficulty of assignments]'>,
#         <AxesSubplot:title={'center':'Explains concepts in an understandable way'}, xlabel='[Degree of difficulty of assignments]'>,
#         <AxesSubplot:title={'center':'Provides support for students going above and beyond'}, xlabel='[Degree of difficulty of assignments]'>],
#        [<AxesSubplot:title={'center':'Solves doubts willingly'}, xlabel='[Degree of difficulty of assignments]'>,
#         <AxesSubplot:title={'center':'Structuring of the course'}, xlabel='[Degree of difficulty of assignments]'>,
#         <AxesSubplot:title={'center':'Student ID'}, xlabel='[Degree of difficulty of assignments]'>],
#        [<AxesSubplot:title={'center':'Unnamed: 0'}, xlabel='[Degree of difficulty of assignments]'>,
#         <AxesSubplot:title={'center':'Use of presentations'}, xlabel='[Degree of difficulty of assignments]'>,
# ...

# %%
sns.countplot(x='Structuring of the course' , data=df)
plt.show()

# %%
#pre-processing
x=np.array(df.drop(['Course recommendation based on relevance'],1))
y=np.array(df['Course recommendation based on relevance'])
x
# Out:
# array([[   0,  340,    5, ...,    9,    2,    1],
#        [   1,  253,    6, ...,    2,    1,    2],
#        [   2,  680,    7, ...,    4,    2,    3],
#        ...,
#        [ 998,  199,    9, ...,    8,    1,    1],
#        [ 999,  539,   10, ...,    3,    4,   10],
#        [1000,  759,    7, ...,    1,    5,    9]], dtype=int64)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
rescaledx= scaler.fit_transform(x)
rescaledx
# Out:
# array([[0.        , 0.34      , 0.        , ..., 0.88888889, 0.11111111,
#         0.        ],
#        [0.001     , 0.253     , 0.2       , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.002     , 0.68      , 0.4       , ..., 0.33333333, 0.11111111,
#         0.22222222],
#        ...,
#        [0.998     , 0.199     , 0.8       , ..., 0.77777778, 0.        ,
#         0.        ],
#        [0.999     , 0.539     , 1.        , ..., 0.22222222, 0.33333333,
#         1.        ],
#        [1.        , 0.759     , 0.4       , ..., 0.        , 0.44444444,
#         0.88888889]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
fit = pca.fit(x)
features = fit.transform(x)
features
# Out:
# array([[-240.41432934, -466.68958756,    0.98341961],
#        [-178.19036722, -527.50101432,    4.5275033 ],
#        [-479.41862342, -224.8597212 ,    2.6935741 ],
#        ...,
#        [ 564.97793743,  139.30060445,    0.69344455],
#        [ 325.26816511,  380.42585195,    2.20537868],
#        [ 170.412104  ,  536.69401445,    0.65428024]])

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                              0
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(fill_value=np.nan, strategy = 'mean')
X=imputer.fit_transform(df)
X
# Out:
# array([[   0.,  340.,    5., ...,    2.,    1.,    8.],
#        [   1.,  253.,    6., ...,    1.,    2.,    9.],
#        [   2.,  680.,    7., ...,    2.,    3.,    1.],
#        ...,
#        [ 998.,  199.,    9., ...,    1.,    1.,    2.],
#        [ 999.,  539.,   10., ...,    4.,   10.,    1.],
#        [1000.,  759.,    7., ...,    5.,    9.,    9.]])

# %%
dropedDf = df.dropna()

# %%
dropedDf
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 0              0         340                             5
# 1              1         253                             6
# 2              2         680                             7
# 3              3         806                             9
# 4              4         632                             8
# ...          ...         ...                           ...
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# ...
